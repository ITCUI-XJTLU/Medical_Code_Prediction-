# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
path="/content/drive/My Drive/MIMIC"

os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive/
# ['caml-mimic',
#  'Multi-Filter-Residual-Convolutional-Neural-Network',
#  'LAAT',
#  'LAAT_Run.ipynb',
#  'CALM_RUN.ipynb',
#  'Process_Data',
#  'MResCNN_RUN.ipynb',
#  'Find_MN.ipynb',
#  'MResCNN_RUN_2.ipynb',
#  'outputs',
#  'Transformer_MCP_1.ipynb']

# %%
! git clone https://github.com/foxlf823/Multi-Filter-Residual-Convolutional-Neural-Network.git
# Out:
# fatal: destination path 'Multi-Filter-Residual-Convolutional-Neural-Network' already exists and is not an empty directory.

# %%
os.chdir("/content/drive/My Drive/MIMIC/Multi-Filter-Residual-Convolutional-Neural-Network")

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.7 MB 7.2 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 8.4 MB 42.9 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 51.8 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 62.2 MB/s
# ...
#      |████████████████████████████████| 128 kB 62.5 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 29.8 MB/s
# ...
#      |████████████████████████████████| 69 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 157 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 430 kB 52.3 MB/s
# ...
#      |████████████████████████████████| 81 kB 10.4 MB/s
# ...
#      |████████████████████████████████| 190 kB 46.3 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 46.9 MB/s
# ...
#      |████████████████████████████████| 133 kB 56.1 MB/s
# ...

# %%
import spacy 
import nltk
# !python3 -m spacy download en_core_web_sm # 下载英文
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.1 MB 9.2 MB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.1.0-py3-none-any.whl size=11074433 sha256=d42c5c35994cbdca0b15c85883e0dd3781788fbaba31285b207bf85b9eaa43fd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-drnf7dzf/wheels/59/4f/8c/0dbaab09a776d1fa3740e9465078bfd903cc22f3985382b496
# Successfully built en-core-web-sm
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.4.0
#     Uninstalling en-core-web-sm-3.4.0:
#       Successfully uninstalled en-core-web-sm-3.4.0
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python preprocess_mimic3.py
# Out:
# Traceback (most recent call last):
#   File "preprocess_mimic3.py", line 17, in <module>
#     dfdiag = pd.read_csv('%s/DIAGNOSES_ICD.csv' % args.MIMIC_3_DIR)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 685, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 457, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 895, in __init__
#     self._make_engine(self.engine)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 1135, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 1917, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
# KeyboardInterrupt
# ^C

# %%
# Train and test using top-50 MIMIC-III data
# !python main.py -data_path ./data/mimic3/train_50.csv \
                -vocab ./data/mimic3/vocab.csv \
                -Y full -model MultiResCNN \
                -embed_file ./data/mimic3/processed_full.embed \
                -criterion prec_at_5 \
                -gpu 0 \
                -tune_wordemb
# Out:
# Namespace(DATA_DIR='./data', MAX_LENGTH=2500, MIMIC_2_DIR='./data/mimic2', MIMIC_3_DIR='./data/mimic3', MODEL_DIR='./models', Y='full', batch_size=16, bert_dir=None, command='python main.py -data_path ./data/mimic3/train_50.csv -vocab ./data/mimic3/vocab.csv -Y full -model MultiResCNN -embed_file ./data/mimic3/processed_full.embed -criterion prec_at_5 -gpu 0 -tune_wordemb', conv_layer=1, criterion='prec_at_5', data_path='./data/mimic3/train_50.csv', dropout=0.2, elmo_dropout=0, elmo_gamma=0.1, elmo_options_file='elmo_small/elmo_2x1024_128_2048cnn_1xhighway_options.json', elmo_tune=False, elmo_weight_file='elmo_small/elmo_2x1024_128_2048cnn_1xhighway_weights.hdf5', embed_file='./data/mimic3/processed_full.embed', filter_size='3,5,9,15,19,25', gpu=0, lr=0.0001, model='MultiResCNN', n_epochs=500, num_filter_maps=50, patience=10, random_seed=1, test_model=None, tune_wordemb=True, use_elmo=False, use_ext_emb=False, version='mimic3', vocab='./data/mimic3/vocab.csv', weight_decay=0)
# ...
